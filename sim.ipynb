# %% [markdown]
# # CPU scheduling gantt chart simulator

# %% [markdown]
# > importing the needed modules (and forcing the notebook to show graph)

# %%
# %matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# > importing the files that contains the helper functions needed by the code

# %%
from helper.helper_functions import remove_duplicate

# %% [markdown]
# ## The function that generates the gantt graph from the input
#
# > the function takes input in this format :
#
# ```python
# timeline = [
#     [ process_id , start-time , duration ] ,
#     [...]
# ]
# ```

# %%
def create_gantt_chart(time_line,question,option):

    timeline = time_line

    processes = []
    for i in timeline:
        processes.append(i[0])

    y_position = {}
    position = 0
    for p in processes:
        if p in y_position:
            continue
        y_position[p] = position
        position = position+(len(remove_duplicate(processes)))

    fig, (gantt_chart, summary_area, table_area) = plt.subplots(3, 1, figsize=(20, 12), gridspec_kw={"height_ratios": [1.6,0.1,0.8]})

    points = []
    header_for_table = ["Process ID","Arrival Time","Burst Time","Completion Time","Turnaround Time","Waiting Time"]
    rows_for_table = []
    avg_waiting_time = []
    avg_turnaround_time = []
    i = 0
    for process, start, duration in timeline:
        y = y_position[process]

        gantt_chart.broken_barh(
            [(start,duration)],
            (y_position[process], 2),
            facecolors = "lightblue",
            edgecolors = "lightgrey"
        )

        x_center = (start + (start+duration))/2
        y_center = y + 1

        gantt_chart.text(x_center,y_center,process,ha='center',va='center',fontsize=16)
        gantt_chart.text(start+0.1,y_center,start,ha='center',va='center')
        gantt_chart.text((start+duration)-0.1,y_center,start+duration,ha='center',va='center')

        points.append(start)
        points.append(start+duration)

        process_id = question[i][0]
        arrival_time = question[i][2]
        burst_time = question[i][1]
        completion_time = start+question[i][1]
        turnaround_time = (completion_time)-question[i][2]
        avg_turnaround_time.append(turnaround_time)
        waiting_time = (turnaround_time)-question[i][1]
        avg_waiting_time.append(waiting_time)
        rows_for_table.append([process_id,arrival_time,burst_time,completion_time,turnaround_time,waiting_time])
        i+=1

    gantt_chart.set_xticks(points)

    y_ticks = []
    for y in y_position.values():
        y_ticks.append(y+1)

    gantt_chart.set_yticks(y_ticks)
    gantt_chart.set_yticklabels(remove_duplicate(processes))

    gantt_chart.set_xlabel("time(millisecond)")
    gantt_chart.set_ylabel("process id")
    gantt_chart.set_title("cpu scheduling gantt chart")

    gantt_chart.set_xlim(0,(timeline[-1][1]+timeline[-1][2]+1))
    gantt_chart.grid(True,color='lightgrey')

    table_area.axis('off')
    table = table_area.table(
        cellText=rows_for_table,
        colLabels=header_for_table,
        colColours=["lightblue"] * len(header_for_table),
        loc='center',
        cellLoc='center'
    )
    table.auto_set_font_size(False)
    table.set_fontsize(12)
    table.scale(1.0, 1.8)

    summary_area.axis('off')
    summary_area.text(
        0.5, 0.5, 
        f"Average Turnaround Time: {sum(avg_turnaround_time)/len(avg_turnaround_time)} ms   |   Average Waiting Time: {sum(avg_waiting_time)/len(avg_waiting_time)} ms   |   CPU Utilization: {"not calculated yet"} %", # /sum(timeline[-1][2],timeline[-1][1])
        ha='center', va='center',
        fontsize=12,
        bbox=dict(boxstyle='round,pad=0.6', facecolor='#dbeef3', edgecolor='#4682b4', linewidth=1)
    )

    plt.tight_layout()
    if option == 1 :
        plt.savefig("first_come_first_serve_graph.png")
    elif option == 2 :
        plt.savefig("shortest_job_first_graph.png")
    else : 
        plt.savefig("_gantt_chart.png")
    plt.show()

# %% [markdown]
# ## 1. First Come First Serve
#
# > the function input format :
# ```py
# query = [
#     [ process_id , cpu-burst , arrival-time ] ,
#     [...]
# ]
# ```
# > the return format :
# ```py
# answer = [
#     [ process_id , start-time , duration ] ,
#     [...]
# ]
# ```

# %%
def first_come_first_serve(query,context_switching=0):

    question = query
    question.sort(key=lambda x : x[2])

    answer = []

    waiting = 0

    for i in range (len(question)) :
        if i == 0 :
            waiting = question[0][2]
        elif (answer[i-1][1]+answer[i-1][2]) >= question[i][2]:
            waiting = answer[i-1][1]+answer[i-1][2]
        elif (answer[i-1][1]+answer[i-1][2]) < question[i][2]:
            waiting = question[i][2]

        answer.append([question[i][0],waiting+context_switching,question[i][1]])

    return answer

# %% [markdown]
# ## 2. Shortest Job First

# %%
def shortest_job_first(query):

    question = query
    question.sort(key=lambda x : x[2])

    answer = []
    queue = []

    arrival_times = []
    for i in question:
        arrival_times.append(i[2])
    arrival_times = remove_duplicate(arrival_times)

    for i in arrival_times:
        temp = []
        for j in range(len(question)):
            if i == question[j][2]:
                temp.append(question[j])
        temp.sort(key=lambda x : x[1])
        queue.append(temp)

    answer_i = -1

    for i in range (len(queue)):
        for j in range (len(queue[i])):
            if i == 0 and j == 0:
                waiting = queue[i][j][2]
            elif answer[answer_i][1]+answer[answer_i][2] >= queue[i][j][2]:
                waiting = answer[answer_i][1]+answer[answer_i][2]
            elif answer[answer_i][1]+answer[answer_i][2] < queue[i][j][2]:
                waiting = queue[i][j][2]

            answer.append([queue[i][j][0],waiting,queue[i][j][1]])
            answer_i += 1

    return answer

# %% [markdown]
# ## The Main function :
#
# > the job is to handle the user inputs and the different function calling

# %%
def main(option,question):

    if option == 1 :
        answer = first_come_first_serve(question)
    elif option == 2 :
        answer = shortest_job_first(question)
    else : 
        print("Wrong Input")
        return

    create_gantt_chart(answer,question,option)

# %% [markdown]
# ## The Code Entry Point :
#
# > takes input from the user and gives to the main function

# %%
if __name__ == "__main__":

    # first come first serve question
    question = [
        ['P1',10,0],
        ['P2',5,15],
        ['P3',5,15],
        ['P4',10,23],
    ]

    query_1 = [["P1", 4, 0], ["P2", 3, 1], ["P3", 1, 2], ["P4", 2, 3]]
    query_2 = [["P1", 3, 0],["P2", 2, 5],["P3", 4, 8],]
    query_3 = [["P1", 3, 4],["P2", 4, 2],["P3", 2, 4],["P4", 1, 10],]

    process_test = [
        ["P1", 5, 1], 
        ["P2", 2, 3],  
        ["P3", 1, 5],  
        ["P4", 4, 7],  
        ["P5", 4, 7],  
        ["P6", 3, 7],  
        ["P7", 8, 28],
        ["P8", 2, 35], 
    ]

    main(2,process_test)
